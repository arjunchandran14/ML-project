# %% [markdown]
# # <b><u> Project Title : Predicting loan default in banking </u></b>

# %% [markdown]
# # Business Problem:

# %% [markdown]
# "Predicting Loan Defaults in Banking: Developing an ML Model to Mitigate Losses"
#
# This problem involves leveraging machine learning algorithms to analyze historical data on loan applications, customer profiles, and economic indicators to predict the likelihood of a customer defaulting on their loan. By accurately identifying high-risk borrowers early in the process, banks can take proactive measures such as adjusting interest rates, modifying repayment terms, or denying loans to mitigate potential losses. This project aims to optimize the bank's lending process, improve risk management strategies, and ultimately reduce financial losses due to loan defaults.

# %% [markdown]
# ## Project Workflow
#
# 1. **Data Collection:** Gather various attributes related to loans and borrowers, including financial details, credit history, employment information, and loan performance.
#
#
# 2. **Data Preprocessing:** Clean and prepare the data for analysis, including handling missing values, encoding categorical variables, and scaling features.
#
#
# 3. **Exploratory Data Analysis (EDA):** Explore the dataset to gain insights into the distribution of variables, relationships, and potential patterns related to loan default.
#
#
# 4. **Feature Engineering:** Create or transform features that can improve the predictive power of the model.
#
#
# 5. **Model Building:** Train and evaluate machine learning models for predicting the probability of default. Common models include logistic regression, decision trees, random forests, and gradient boosting.
#
#
# 6. **Model Evaluation:** Use the metrics to assess the model's performance.
#
#
# 7. **Model Deployment:** If the model performs well, consider deploying it for real-time credit risk assessment.
#
#
# 8. **Documentation and Reporting:** Document the project's findings, including model performance, insights from EDA, and recommendations for risk management.

# %% [markdown]
# # Data Understanding:
#
#
# `ID` - unique identifier for each loan application
#
# `Loan Amount` - the amount requested by the borrower
#
# `Funded Amount` - the amount funded by investors for the loan
#
# `Funded Amount Investor` - the amount funded by investors for the loan
#
# `Term` - the length of the loan term in months
#
# `Batch Enrolled` - the batch enrollment method for the loan
#
# `Interest Rate` - the interest rate on the loan
#
# `Grade` - the Lending Club assigned loan grade
#
# `Sub Grade` - the Lending Club assigned loan subgrade
#
# `Employment Duration` - the employment length of the borrower
#
# `Home Ownership` - the type of home ownership of the borrower
#
# `Verification Status` - indicates if the borrower’s income was verified
#
# `Loan Title` - the title of the loan as provided by the borrower
#
# `Debit to Income` - the borrower’s debt-to-income ratio
#
# `Delinquency - two years` - the number of times the borrower has been delinquent in the past two years
#
# `Inquires - six months` - the number of inquiries made on the borrower’s credit in the past six months
#
# `Open Account` - the number of open credit lines in the borrower's credit file
#
# `Public Record` - the number of derogatory public records on the borrower's credit file
#
# `Revolving Balance` - the balance on the borrower's revolving credit accounts
#
# `Revolving Utilities` - the amount of the borrower's revolving credit that is currently in use
#
# `Total Accounts` - the total number of credit lines the borrower has
#
# `Initial List Status` - the initial listing status of the loan
#
# `Total Received Interest` - total interest received to date
#
# `Total Received Late Fee` - total late fees received to date
#
# `Recoveries` - post charge off gross recovery
#
# `Collection Recovery Fee` - post charge off collection fee
#
# `Collection 12 months Medical` - number of collections in medical categories in the last 12 months
#
# `Application Type` - indicates whether the loan is an individual or joint application
#
# `Last week Pay` - the last week’s payment on the loan
#
# `Total Collection Amount` - total amount due after the charged off
#
# `Total Current Balance` - total current balance of all accounts
#
# `Total Revolving Credit Limit` - total revolving credit limit
#
# `Loan Status` - current status of the loan
#
# `Debt-to-Income Ratio` - the borrower's debt-to-income ratio
#
# `Credit Utilization Ratio` - the borrower's credit utilization ratio
#
# `Time Since Last Delinquency` - the number of months since the borrower's last delinquency

# %% [markdown]
# # Objective:

# %% [markdown]
# This project aims to optimize the bank's lending process, improve risk management strategies, and ultimately reduce financial losses due to loan defaults.

# %%
# Importing all basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # DATA COLLECTION AND PREPROCESSING

# %% [markdown]
# ### Data structure

# %%
df = pd.read_csv(r"C:\Users\arjun\Downloads\train.csv")

# %%
df.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#     Recoveries Collection Recovery Fee Collection 12 months Medical  \
# ...

# %%
df.shape
# Out:
# (67463, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67463 entries, 0 to 67462
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            67463 non-null  int64
#  1   Loan Amount                   67463 non-null  int64
#  2   Funded Amount                 67463 non-null  int64
#  3   Funded Amount Investor        67463 non-null  float64
#  4   Term                          67463 non-null  int64
#  5   Batch Enrolled                67463 non-null  object
#  6   Interest Rate                 67463 non-null  float64
#  7   Grade                         67463 non-null  object
#  8   Sub Grade                     67463 non-null  object
#  9   Employment Duration           67463 non-null  object
#  10  Home Ownership                67463 non-null  float64
#  11  Verification Status           67463 non-null  object
# ...

# %%
# Separate numerical and categorical columns
numerical_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(exclude=['number']).columns

# Descriptive analysis for numerical columns
numerical_analysis = df[numerical_cols].describe()

# Descriptive analysis for categorical columns
categorical_analysis = df[categorical_cols].describe(include=['object'])

# Print the results
print("Descriptive statistics for numerical columns:")
print(numerical_analysis)
print("\nDescriptive statistics for categorical columns:")
print(categorical_analysis)
# Out:
# Descriptive statistics for numerical columns:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  6.746300e+04  67463.000000   67463.000000            67463.000000
# mean   2.562761e+07  16848.902776   15770.599114            14621.799323
# std    2.109155e+07   8367.865726    8150.992662             6785.345170
# min    1.297933e+06   1014.000000    1014.000000             1114.590204
# 25%    6.570288e+06  10012.000000    9266.500000             9831.684984
# 50%    1.791565e+07  16073.000000   13042.000000            12793.682170
# 75%    4.271521e+07  22106.000000   21793.000000            17807.594120
# max    7.224578e+07  35000.000000   34999.000000            34999.746430
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  67463.000000   67463.000000    67463.000000     67463.000000
# mean      58.173814      11.846258    80541.502522        23.299241
# ...

# %%
#checking for unique values
df.nunique()
# Out:
# ID                              67463
# Loan Amount                     27525
# Funded Amount                   24548
# Funded Amount Investor          67441
# Term                                3
# Batch Enrolled                     41
# Interest Rate                   67448
# Grade                               7
# Sub Grade                          35
# Employment Duration                 3
# Home Ownership                  67454
# Verification Status                 3
# Payment Plan                        1
# Loan Title                        109
# Debit to Income                 67454
# Delinquency - two years             9
# Inquires - six months               6
# Open Account                       36
# Public Record                       5
# Revolving Balance               20582
# Revolving Utilities             67458
# Total Accounts                     69
# Initial List Status                 2
# Total Received Interest         67451
# Total Received Late Fee         67380
# ...

# %%
# Account Delinquent and Payment plan has only one value which is irrelavent hence drop it
df.drop(['Accounts Delinquent','Payment Plan'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                              0
# Loan Amount                     0
# Funded Amount                   0
# Funded Amount Investor          0
# Term                            0
# Batch Enrolled                  0
# Interest Rate                   0
# Grade                           0
# Sub Grade                       0
# Employment Duration             0
# Home Ownership                  0
# Verification Status             0
# Loan Title                      0
# Debit to Income                 0
# Delinquency - two years         0
# Inquires - six months           0
# Open Account                    0
# Public Record                   0
# Revolving Balance               0
# Revolving Utilities             0
# Total Accounts                  0
# Initial List Status             0
# Total Received Interest         0
# Total Received Late Fee         0
# Recoveries                      0
# Collection Recovery Fee         0
# Collection 12 months Medical    0
# ...

# %% [markdown]
# there is no null value

# %%
#Checking for duplicates and dropping if any
df[df.duplicated(keep=False)]
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67463 entries, 0 to 67462
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            67463 non-null  int64
#  1   Loan Amount                   67463 non-null  int64
#  2   Funded Amount                 67463 non-null  int64
#  3   Funded Amount Investor        67463 non-null  float64
#  4   Term                          67463 non-null  int64
#  5   Batch Enrolled                67463 non-null  object
#  6   Interest Rate                 67463 non-null  float64
#  7   Grade                         67463 non-null  object
#  8   Sub Grade                     67463 non-null  object
#  9   Employment Duration           67463 non-null  object
#  10  Home Ownership                67463 non-null  float64
#  11  Verification Status           67463 non-null  object
# ...

# %% [markdown]
# ## 0 = Not in default
# ## 1 = in default

# %%
df['Loan Status'].value_counts() #Training ddata is Highly imbalanced dataset 0 refer
# Out:
# Loan Status
# 0    61222
# 1     6241
# Name: count, dtype: int64

# %%
df['Loan Status'].value_counts(normalize=True)*100
# Out:
# Loan Status
# 0    90.749003
# 1     9.250997
# Name: proportion, dtype: float64

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# # Dependent Variable:

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'Loan Status', data = df)
# Out:
# <Axes: xlabel='Loan Status', ylabel='count'>

# %%
df['Loan Status'].value_counts(normalize=True)*100
# Out:
# Loan Status
# 0    90.749003
# 1     9.250997
# Name: proportion, dtype: float64

# %% [markdown]
# ##### As we can see from above graph that both classes are not in proportion and we have imbalanced dataset.

# %% [markdown]
# # Independent Variable:

# %% [markdown]
# # Categorical Features
# We have few categorical features in our dataset. Let'Check how they are related with out target class.

# %%
df.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#    Total Received Late Fee   Recoveries Collection Recovery Fee  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Batch Enrolled', 'Interest Rate', 'Grade', 'Sub Grade',
#        'Employment Duration', 'Home Ownership', 'Verification Status',
#        'Loan Title', 'Debit to Income', 'Delinquency - two years',
#        'Inquires - six months', 'Open Account', 'Public Record',
#        'Revolving Balance', 'Revolving Utilities', 'Total Accounts',
#        'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Application Type', 'Last week Pay',
#        'Total Collection Amount', 'Total Current Balance',
#        'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %% [markdown]
# ### Distribution of Public Record by Loan Status

# %%
df["Public Record"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 67458    0
# 67459    0
# 67460    1
# 67461    0
# 67462    0
# Name: Public Record, Length: 67463, dtype: int64

# %%
df['Public Record'].value_counts(normalize=True)*100
# Out:
# Public Record
# 0    93.193306
# 1     6.126321
# 2     0.296459
# 4     0.272742
# 3     0.111172
# Name: proportion, dtype: float64

# %%
# Set up the figure
sns.set(style="whitegrid", font_scale=1.2)
fig, ax = plt.subplots(figsize=(12, 8))

# Create the visualization
sns.histplot(data=df, x="Public Record", hue="Loan Status", multiple="stack", kde=True, ax=ax)



# Add a title and axis labels
plt.title("Distribution of Public Record by Loan Status")
plt.xlabel("Public Record")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# A derogatory public record refers to negative items or entries on a person’s credit report. These entries indicate financial obligations that were not paid as agreed, which can significantly impact creditworthiness.
# Derogatory public records are typically associated with risk and may hinder an individual’s ability to qualify for credit or other financial services.

# %% [markdown]
# ## Loan Amount Distribution: Plot a histogram to visualize the distribution of loan amounts.

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Loan Amount'], bins=20, color='skyblue')
plt.title('Loan Amount Distribution')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### Interest Rate vs. Loan Grade

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Grade'], df['Interest Rate'], alpha=0.5)
plt.title('Interest Rate vs. Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Interest Rate')
plt.show()

# %% [markdown]
# #### Loan Status Breakdown

# %%
plt.figure(figsize=(8, 8))
df['Loan Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Loan Status Breakdown')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### Loan Purpose vs. Loan Amount

# %%
# Plotting Loan Purpose vs. Loan Amount
plt.figure(figsize=(12, 6))
sns.boxplot(x='Loan Title', y='Loan Amount', data=df)
plt.xticks(rotation=45)
plt.title('Loan Purpose vs. Loan Amount')
plt.xlabel('Loan Purpose')
plt.ylabel('Loan Amount')
plt.show()

# %% [markdown]
# ### Plotting Interest Rate vs. Grade/Sub Grade

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Grade', y='Interest Rate', data=df, order=['A', 'B', 'C', 'D', 'E', 'F', 'G'])
plt.title('Interest Rate vs. Grade')
plt.xlabel('Grade')
plt.ylabel('Interest Rate')
plt.show()

# %% [markdown]
# ###### Revolving Balance vs. Loan Status

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Loan Status', y='Revolving Balance', data=df)
plt.title('Revolving Balance vs. Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Revolving Balance')
plt.show()

# %% [markdown]
# #### Verification Status vs. Loan Status

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Verification Status', hue='Loan Status', data=df)
plt.title('Verification Status vs. Loan Status')
plt.xlabel('Verification Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Loan Term vs. Loan Status

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Term', hue='Loan Status', data=df)
plt.title('Loan Term vs. Loan Status')
plt.xlabel('Loan Term')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Total Current Balance

# %%
# Set up the figure
sns.set(style="whitegrid", font_scale=1.2)
fig, ax = plt.subplots(figsize=(12, 8))

# Create the visualization
sns.histplot(data=df, x="Total Current Balance", hue="Loan Status", multiple="stack", kde=True, ax=ax)



# Add a title and axis labels
plt.title("Distribution of Total Current Balance by Loan Status")
plt.xlabel("Total Current Balance")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# # Deliquency

# %%
# Set up the figure
sns.set(style="whitegrid", font_scale=1.2)
fig, ax = plt.subplots(figsize=(12, 8))

# Create the visualization
sns.histplot(data=df, x="Delinquency - two years", hue="Loan Status", multiple="stack", kde=True, ax=ax)


# Add a title and axis labels
plt.title("Distribution of Delinquency - Two Years by Loan Status")
plt.xlabel("Delinquency - Two Years")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# ### Debt-to-Income Ratio vs. Loan Status

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Loan Status', y='Debit to Income', data=df)
plt.title('Debt-to-Income Ratio vs. Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Debt-to-Income Ratio')
plt.show()

# %% [markdown]
# ## Loan Status by ownership

# %%
sns.boxplot(x='Loan Status', y='Loan Amount', data=df)
# Out:
# <Axes: xlabel='Loan Status', ylabel='Loan Amount'>

# %% [markdown]
# ## Feature Engineering

# %%
# Select object type data and numerical data columns seperately
cate = [i for i in df.select_dtypes(include='object').columns]
num = [i for i in df.select_dtypes(exclude='object').columns]

# %%
# Lets encode the Batch Enrolled, Sub Grade, Loan titles by the mean value of Loan Status

cols = [i for i in cate if df[i].nunique()>10]

for feature in cols:
    g = dict(df.groupby(feature)['Loan Status'].mean())
    df[feature] = df[feature].replace(g)

# %%
# Perform OneHot Encoding for the remaining categorical features
df = pd.get_dummies(df)

print(df.shape)
# Out:
# (67463, 45)

# %%
from sklearn.model_selection import train_test_split
#Splitting data into train and test
X = df.drop('Loan Status', axis=1)
y = df['Loan Status']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = 0.7)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the training data and transform it
X_train = scaler.fit_transform(X_train)

# Transform the test data using the scaler fitted to the training data
X_test = scaler.transform(X_test)

# %% [markdown]
# the method that we will use to adress the class imbalance in the training data is Random Over sampling. Random oversampling involves randomly duplicating the minority class samples in the dataset until the proportion of the positive and negative classes becomes balanced. This technique increases the representation of the minority class in the dataset and helps the model learn better the features that distinguish the minority class from the majority class.

# %%
from imblearn.over_sampling import RandomOverSampler

# Initialize a RandomOverSampler object
oversample = RandomOverSampler(sampling_strategy='minority')


# Viewing original y_train class distribution
print(y_train.value_counts()) 

# Fitting SMOTE to training data
X_train_resampled, y_train_resampled =oversample.fit_resample(X_train, y_train) 

# Previewing synthetic sample class distribution
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Loan Status
# 0    42842
# 1     4382
# Name: count, dtype: int64
# Loan Status
# 0    42842
# 1    42842
# Name: count, dtype: int64

# %%
# Get the column names from the original X dataframe
column_names = X.columns

# Create a new dataframe from the resampled X_train data with the column names
scaled_df_train = pd.DataFrame(X_train_resampled, columns=column_names)

# Display the first 5 rows of the new dataframe
scaled_df_train.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor      Term  \
# 0 -0.945715     1.556170      -0.921097               -0.778757  0.248885
# 1  1.203992     0.117151       0.848428               -0.421333 -0.046804
# 2 -1.112032    -1.604310      -0.610351                1.141852 -0.046804
# 3  0.719891    -1.142349       0.013964               -0.531500  0.248885
# 4  0.557717     1.363128      -0.603236               -1.083681  0.248885
#
#    Batch Enrolled  Interest Rate  Sub Grade  Home Ownership  Loan Title  ...  \
# 0        0.502403      -0.268026   0.491175        1.353041    0.117407  ...
# 1       -1.081429      -0.689692   0.162498        1.791153   -0.160782  ...
# 2       -0.049456      -0.428740  -0.164403        0.315805    0.117407  ...
# 3       -2.002368       0.057693  -0.793033       -0.762472   -0.160782  ...
# 4       -0.717966      -0.755488  -0.093675       -0.763250    0.117407  ...
#
# ...

# %%
# This line of code prints the count of each class in the target variable of the training data.


print(pd.Series(y_train_resampled).value_counts())
# Out:
# Loan Status
# 0    42842
# 1    42842
# Name: count, dtype: int64

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Building a Logistic Regression Model

# %%
from sklearn.linear_model  import LogisticRegression

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
   
    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on both training and testing sets
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Calculate evaluation metrics for training and testing sets
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred)
    train_recall = recall_score(y_train, y_train_pred)
    train_f1 = f1_score(y_train, y_train_pred)
    train_roc_score = roc_auc_score(y_train, y_train_pred)

    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)
    test_roc_score = roc_auc_score(y_test, y_test_pred)

    # Create a dictionary to store the results
    evaluation_results = {
        'Train Accuracy': train_accuracy,
        'Train Precision': train_precision,
        'Train Recall': train_recall,
        'Train F1 Score': train_f1,
        'Train ROC AUC Score': train_roc_score,
        'Test Accuracy': test_accuracy,
        'Test Precision': test_precision,
        'Test Recall': test_recall,
        'Test F1 Score': test_f1,
        'Test ROC AUC Score': test_roc_score,
        'y_pred_train': y_train_pred,
        'y_pred_test': y_test_pred
    }

    return evaluation_results

# %%
def plot_confusion_matrix(y_true, y_pred, labels = ['Not Defaulter', 'Defaulter']):
    
    # Create the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Create a heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
    
    # Add labels and title
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    
    # Display the plot
    plt.show()

# %%
logistic_model = LogisticRegression()
results_lr = evaluate_model(logistic_model,X_train_resampled, X_test, y_train_resampled, y_test)
results_lr
# Out:
# {'Train Accuracy': 0.5365995985248121,
#  'Train Precision': 0.5391061452513967,
#  'Train Recall': 0.5045516082349096,
#  'Train F1 Score': 0.5212568424606333,
#  'Train ROC AUC Score': 0.5365995985248121,
#  'Test Accuracy': 0.5661346904491329,
#  'Test Precision': 0.10535917901938427,
#  'Test Recall': 0.4970414201183432,
#  'Test F1 Score': 0.1738639570985041,
#  'Test ROC AUC Score': 0.5350821899285948,
#  'y_pred_train': array([0, 0, 0, ..., 0, 0, 1], dtype=int64),
#  'y_pred_test': array([1, 0, 1, ..., 0, 1, 1], dtype=int64)}

# %%
plot_confusion_matrix(y_test, results_lr['y_pred_test'])

# %% [markdown]
# ### Interpretation

# %% [markdown]
# True positive: 10482 (actual non-defaults correctly identified as non-defaults
#
# True negative: 918 (actual defaults correctly identified as defaults)
#
# False negative: 941(actual defaults incorrectly identified as non-defaults)
#
# False positive: 7898 (actual non-defaults incorrectly identified as defaults)

# %% [markdown]
# The model's performance on the training set is slightly better than random guessing, as indicated by the metrics.
# However, on the test set, the performance is still suboptimal, with low precision and F1 score.
# The model seems to have some predictive power as indicated by the ROC AUC scores, but it's not performing well in terms of precision and recall, especially on the test set.

# %% [markdown]
# # Descsion Tree:
# The DecisionTreeClassifier algorithm is a classification algorithm that constructs a tree-like model of decisions based on the training data. It partitions the input feature space recursively, using a top-down approach, into smaller and smaller subsets that are as homogeneous as possible with respect to the target variable. The algorithm selects the feature that best separates the data into the most homogeneous subsets at each node. The decision tree model can be represented as a flowchart, where the internal nodes represent decisions based on input features, and the leaf nodes represent class labels. When making a prediction on a new data point, the algorithm traverses the tree from the root to a leaf node, based on the values of the input features, and assigns the class label associated with the leaf node to the new data point.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# StandardScaler is not necessary for Decision Trees since they are not sensitive to the scale
# of the features and scaling can even decrease performance by distorting the shape of the data distribution.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = 0.7)

# %%
# Fitting SMOTE to training data
X_train_resampled, y_train_resampled =oversample.fit_resample(X_train, y_train) 

# Previewing synthetic sample class distribution
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Loan Status
# 0    42842
# 1    42842
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_clf = DecisionTreeClassifier(random_state=42)
results_clf = evaluate_model(tree_clf,X_train_resampled, X_test, y_train_resampled, y_test)
results_clf
# Out:
# {'Train Accuracy': 1.0,
#  'Train Precision': 1.0,
#  'Train Recall': 1.0,
#  'Train F1 Score': 1.0,
#  'Train ROC AUC Score': 1.0,
#  'Test Accuracy': 0.8271159642274816,
#  'Test Precision': 0.09566074950690336,
#  'Test Recall': 0.1043571812802582,
#  'Test F1 Score': 0.09981991252894262,
#  'Test ROC AUC Score': 0.5022874045683119,
#  'y_pred_train': array([0, 0, 0, ..., 1, 1, 1], dtype=int64),
#  'y_pred_test': array([0, 0, 0, ..., 0, 0, 0], dtype=int64)}

# %%
plot_confusion_matrix(y_test,results_clf ['y_pred_test'])

# %% [markdown]
# ### Interpretation

# %% [markdown]
# True positive: 16598 (actual non-defaults correctly identified as non-defaults
#
# True negative: 191 (actual defaults correctly identified as defaults)
#
# False negative: 1668(actual defaults incorrectly identified as non-defaults)
#
# False positive: 1782(actual non-defaults incorrectly identified as defaults)

# %% [markdown]
# The model performs very well on the training set, achieving perfect scores across all metrics, indicating that it has likely memorized the training data.
# However, on the test set, the model's performance significantly drops, with low scores for accuracy, precision, recall, F1 score, and ROC AUC score.
# The discrepancy between training and test performance suggests overfitting, where the model fits too closely to the training data and fails to generalize well to new, unseen data. The model's ability to predict positive instances (precision and recall) on the test set is particularly poor.
# There may be a need to address overfitting through techniques such as regularization, using more diverse training data, or adjusting the model architecture.

# %% [markdown]
# # Decision Tree Grid Search:

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define the parameter grid
param_grid = {
    'max_depth': [5, 10, 15, 20],
                 'min_samples_split': [2, 5, 10],
                 'min_samples_leaf': [1, 2, 4]
}

# %%
# Create a randomized search object
grid_search =GridSearchCV(tree_clf, param_grid, cv=5, n_jobs=-1,scoring='precision')

# %%
results_clfh = evaluate_model(grid_search ,X_train_resampled, X_test, y_train_resampled, y_test)
results_clfh
# Out:
# {'Train Accuracy': 0.8116217730264693,
#  'Train Precision': 0.7644029865525914,
#  'Train Recall': 0.9009149899631202,
#  'Train F1 Score': 0.8270638024320993,
#  'Train ROC AUC Score': 0.8116217730264693,
#  'Test Accuracy': 0.6373832699244034,
#  'Test Precision': 0.09646539027982327,
#  'Test Recall': 0.3523399677245831,
#  'Test F1 Score': 0.15146259683200372,
#  'Test ROC AUC Score': 0.5092766215119107,
#  'y_pred_train': array([0, 0, 0, ..., 1, 1, 0], dtype=int64),
#  'y_pred_test': array([1, 0, 0, ..., 1, 1, 1], dtype=int64)}

# %%
# Print the best hyperparameters
print('Best hyperparameters:', grid_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
plot_confusion_matrix(y_test,results_clfh['y_pred_test'])

# %% [markdown]
# ### Interpretation:

# %% [markdown]
# The model seems to perform significantly better on the training data compared to the test data, indicating potential overfitting.
# The low precision and recall on the test set suggest that the model might not generalize well to unseen data or may need further tuning or feature engineering.
# Further analysis, such as examining the data distribution, model complexity, and potential feature importance, may provide insights into improving the model's performance.

# %% [markdown]
# # Random Forest:
# The RandomForestClassifier algorithm is a popular classification algorithm that builds a collection of decision trees and aggregates their predictions to classify new data points. It is an extension of the DecisionTreeClassifier algorithm that improves its accuracy and reduces overfitting by generating multiple decision trees from bootstrap samples of the training data, where each tree is trained on a different subset of features. The algorithm combines the predictions of the individual trees by either averaging their probabilities or selecting the class with the highest probability. The number of trees and the maximum depth of the trees are hyperparameters that can be tuned to optimize the performance of the algorithm. The RandomForestClassifier algorithm is a powerful and flexible algorithm that can handle high-dimensional datasets with many features and can be used for both classification and regression tasks.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create a RandomForestClassifier object
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
results_rf= evaluate_model(rf,X_train_resampled, X_test, y_train_resampled, y_test)
results_rf
# Out:
# {'Train Accuracy': 1.0,
#  'Train Precision': 1.0,
#  'Train Recall': 1.0,
#  'Train F1 Score': 1.0,
#  'Train ROC AUC Score': 1.0,
#  'Test Accuracy': 0.9081476357527546,
#  'Test Precision': 0.0,
#  'Test Recall': 0.0,
#  'Test F1 Score': 0.0,
#  'Test ROC AUC Score': 0.5,
#  'y_pred_train': array([0, 0, 0, ..., 1, 1, 1], dtype=int64),
#  'y_pred_test': array([0, 0, 0, ..., 0, 0, 0], dtype=int64)}

# %%
plot_confusion_matrix(y_test, results_rf['y_pred_test'])

# %% [markdown]
# ### Interpretation

# %% [markdown]
#  True positive: 18,380 (actual non-defaults correctly identified as non-defaults)
# - True negative: 0 (actual defaults correctly identified as defaults)
# - False negative: 1859 (actual defaults incorrectly identified as non-defaults)
# - False positive: 0 (actual non-defaults incorrectly identified as defaults)
#
#
# The classification report shows that the model has high precision and F1 scores for the 0 class (non-default), but very low scores for the 1 class (default). This indicates that the model is performing well in predicting non-default instances, but is not at all effective at predicting default instances.
#
# This kind of model performance is not useful for predicting loan defaults since it is not able to identify borrowers who are likely to default.
#
#
# The model seems to perform perfectly on the training set but fails to generalize well to unseen data, as evidenced by the poor performance on the test set. It's likely that the model is overfitting to the training data.

# %% [markdown]
# # Random Forest Random Search:

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# %%
rf_param_grid = {'n_estimators': [100, 200],
                 'max_depth': [5, 9, 13],
                 'min_samples_split': [2, 10],
                 'min_samples_leaf': [1, 5],
                 'max_features': ['sqrt']}

# %%
# Create the random search object
random_search = RandomizedSearchCV(estimator=rf,
                                   param_distributions=rf_param_grid,
                                   n_iter=10,  # Number of parameter settings that are sampled
                                   cv=5,  # 5-fold cross-validation
                                   scoring='accuracy',  # Use accuracy as the scoring metric
                                   random_state=42)  # For reproducibility

# %%
# Print the best parameters found
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 13}

# %%
# Print the best score found
print("Best Accuracy:", random_search.best_score_)
# Out:
# Best Accuracy: 0.9520914396569156

# %%
results_rfh = evaluate_model(random_search,X_train_resampled, X_test, y_train_resampled, y_test)
results_rfh
# Out:
# {'Train Accuracy': 0.9714999299752579,
#  'Train Precision': 0.9541571113809074,
#  'Train Recall': 0.9905933429811867,
#  'Train F1 Score': 0.9720338983050847,
#  'Train ROC AUC Score': 0.9714999299752579,
#  'Test Accuracy': 0.8487573496714265,
#  'Test Precision': 0.10564304461942257,
#  'Test Recall': 0.08660570199031738,
#  'Test F1 Score': 0.09518179130948862,
#  'Test ROC AUC Score': 0.5062245049668671,
#  'y_pred_train': array([0, 0, 0, ..., 1, 1, 1], dtype=int64),
#  'y_pred_test': array([0, 0, 0, ..., 0, 1, 0], dtype=int64)}

# %%
plot_confusion_matrix(y_test, results_rfh['y_pred_test'])

# %% [markdown]
# # Xgboost:
#
# The XGBClassifier algorithm is a popular classification algorithm that is based on the gradient boosting framework. It is an optimized version of the gradient boosting algorithm that uses a tree-based ensemble model to predict the class of new data points. The algorithm works by iteratively adding new decision trees to the ensemble, where each new tree is trained to correct the errors of the previous trees. The algorithm uses a gradient descent optimization technique to minimize a loss function, which measures the difference between the predicted class probabilities and the true class labels. The XGBClassifier algorithm uses a regularized version of gradient boosting, which adds penalties to the loss function to prevent overfitting and improve generalization. The algorithm has many hyperparameters that can be tuned to optimize its performance, such as the learning rate, the maximum depth of the trees, the number of trees in the ensemble, and the regularization parameters. The XGBClassifier algorithm is known for its high accuracy and speed and is often used in machine learning competitions and real-world applications.

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
xgb_clf = XGBClassifier(random_state=42)

# %%
results_xgb = evaluate_model(xgb_clf,X_train_resampled, X_test, y_train_resampled, y_test)
results_xgb
# Out:
# {'Train Accuracy': 0.9271625974510994,
#  'Train Precision': 0.9050844456249861,
#  'Train Recall': 0.9544138929088278,
#  'Train F1 Score': 0.9290948545200468,
#  'Train ROC AUC Score': 0.9271625974510995,
#  'Test Accuracy': 0.7813133059933791,
#  'Test Precision': 0.10226216299969011,
#  'Test Recall': 0.17751479289940827,
#  'Test F1 Score': 0.12976799056232796,
#  'Test ROC AUC Score': 0.5099489089633059,
#  'y_pred_train': array([0, 0, 0, ..., 1, 1, 1]),
#  'y_pred_test': array([0, 0, 0, ..., 1, 1, 0])}

# %%
plot_confusion_matrix(y_test, results_xgb['y_pred_test'])

# %%
# Define the XGBClassifier model
xgbc = XGBClassifier(n_jobs=-1)

# %%
# Define the parameter grid for Randomized Grid Search
param_grid =  {'n_estimators': [100, 200],
              'max_depth': [5, 9],
              'learning_rate': [0.01, 0.1],
              'subsample': [0.5, 0.8],
              'colsample_bytree': [0.5, 0.8]}

# %%
# Perform Randomized Grid Search with 10-fold cross validation
xgb_grid =GridSearchCV(xgbc, param_grid, cv=5, scoring='precision', n_jobs=-1)

# %%
results_xgbh = evaluate_model(xgb_grid ,X_train_resampled, X_test, y_train_resampled, y_test)
results_xgbh
# Out:
# {'Train Accuracy': 0.9985995051584894,
#  'Train Precision': 0.9983435983575961,
#  'Train Recall': 0.9988562625460996,
#  'Train F1 Score': 0.9985998646535832,
#  'Train ROC AUC Score': 0.9985995051584893,
#  'Test Accuracy': 0.8951035130194179,
#  'Test Precision': 0.1,
#  'Test Recall': 0.01775147928994083,
#  'Test F1 Score': 0.03015075376884422,
#  'Test ROC AUC Score': 0.500796305477397,
#  'y_pred_train': array([0, 0, 0, ..., 1, 1, 1]),
#  'y_pred_test': array([0, 0, 0, ..., 1, 0, 0])}

# %%
plot_confusion_matrix(y_test, results_xgbh['y_pred_test'])

# %%
fpr1, tpr1, _ = roc_curve(y_test, results_lr['y_pred_test'])
roc_auc1 = auc(fpr1, tpr1)

fpr2, tpr2, _ = roc_curve(y_test, results_clfh['y_pred_test'])
roc_auc2 = auc(fpr2, tpr2)

fpr2, tpr2, _ = roc_curve(y_test, results_rfh['y_pred_test'])
roc_auc2 = auc(fpr2, tpr2)

fpr2, tpr2, _ = roc_curve(y_test, results_xgbh['y_pred_test'])
roc_auc2 = auc(fpr2, tpr2)

# Repeat the above steps for model3 and its ROC curve and AUC score
plt.figure(figsize=(10, 6))

plt.plot(fpr1, tpr1, color='b', lw=2, label=f'Logistic Regression (AUC = {roc_auc1:.2f})')
plt.plot(fpr2, tpr2, color='r', lw=2, label=f'decission tree (AUC = {roc_auc2:.2f})')
plt.plot(fpr2, tpr2, color='r', lw=2, label=f'random forest (AUC = {roc_auc2:.2f})')
plt.plot(fpr2, tpr2, color='r', lw=2, label=f'xgboost (AUC = {roc_auc2:.2f})')


# Plot the ROC curve for model3 with its AUC score

plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Reasons for selecting  xgboost as final model:

# %% [markdown]
# 1- High Training Accuracy and Performance Metrics:
# The model achieved very high accuracy, precision, recall, F1 score, and ROC AUC score on the training set (all above 99.8%). This indicates that the model learned the training data extremely well and can make accurate predictions on seen data.
#
# 2- Reasonable Test Accuracy:
# Although there's a drop in performance on the test set compared to the training set, the test accuracy is still high at around 89.51%. This suggests that the model generalizes reasonably well to unseen data.
#
# 3- Test Precision and Recall:
# While the precision and recall on the test set are not as high as on the training set, they are still acceptable for many real-world applications. Despite the low precision, the model may still be useful depending on the specific requirements of the problem.
#
# 4- ROC AUC Score:
# The ROC AUC score on the test set is close to 0.5, indicating that the model's ability to distinguish between classes is not much better than random chance. However, in some cases, this might be acceptable depending on the problem context and the relative importance of other metrics.

# %% [markdown]
# ## Recommendations:

# %% [markdown]
# Targeted advertising for joint application loans: Since joint applications were found to be a significant feature in your model, consider creating targeted ads that promote the benefits of joint applications, such as higher loan amounts, increased chances of approval, and lower interest rates.
#
# Leverage the six-month inquiry feature: Since the number of inquiries made in the six months prior to the loan application was significant, consider creating marketing content that educates potential customers on how to manage their credit inquiries and how to improve their credit score. This can position your company as a helpful resource and build trust with potential customers.
#
# Highlight loan titles that perform well: Loan title was also a significant feature in your model. Consider featuring loan titles that have performed well in the past in your marketing campaigns, highlighting the benefits and key features of those loans.
